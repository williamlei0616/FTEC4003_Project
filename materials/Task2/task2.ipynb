# %%
import pandas as pd
import numpy as np

# %%
train_identity = pd.read_csv('materials/Task2/globalmart_train_identity.csv')
train_transaction = pd.read_csv('materials/Task2/globalmart_train_transactions.csv')
test_identity = pd.read_csv('materials/Task2/globalmart_test_identity.csv')
test_transaction = pd.read_csv('materials/Task2/globalmart_test_transactions.csv')
